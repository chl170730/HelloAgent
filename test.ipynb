# %%
print("Hello, Agent!")
# Out:
# Hello, Agent!

# %%
from datetime import datetime, timezone

# 获取当前 UTC 世界时间
utc_now = datetime.now(timezone.utc)
print("当前世界标准时间(UTC)：", utc_now)
# Out:
# 当前世界标准时间(UTC)： 2026-04-15 03:05:52.915285+00:00
